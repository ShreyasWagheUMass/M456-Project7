# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import scipy as sp
from collections import defaultdict
from itertools import product
import gurobipy as gb
from gurobipy import GRB
from tqdm import tqdm

repeats = json.load(open('../cleanerdata/repeats.json'))
repeats = {int(k):v for k,v in repeats.items()}

locdem = pd.read_excel('../cleanerdata/locdem.xlsx')

q = locdem['Number of pallets'].to_numpy().astype(float).tolist()
q = [0] + q
q.extend([v['dem'] for v in repeats.values()])

locs = pd.read_excel('../cleanerdata/locations.xlsx')
longs, lats = locs['long'].to_numpy().tolist(), locs['lat'].to_numpy().tolist()
longs.extend([longs[v['map']] for v in repeats.values()])
lats.extend([lats[v['map']] for v in repeats.values()])

distmat = pd.read_json('../cleanerdata/distmat.json').to_numpy()
timemat = pd.read_json('../cleanerdata/timemat.json').to_numpy()
def get(i):
    try:
        i = repeats[i]['map']
    except KeyError:
        pass
    return i

mappings = set()
for k,v in repeats.items():
    mappings.add((k, v['map']))
    mappings.add((v['map'], k))

def cost(i,j):
    if (i,j) in mappings:
        return 1e+8
    i,j = get(i), get(j)
    return distmat[i,j]

def time(i,j):
    i,j = get(i), get(j)
    return timemat[i,j]

def location(i):
    return longs[i], lats[i]

# %%
clusters = json.load(open('./clusters.json'))
list(map(lambda x: len(x), clusters))
# Out:
# [3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3]

# %%
Q = 9
iter_count = 0
primary_models = []
Ls = []

for cluster in clusters:
    Neighbours = list(sorted(cluster))
    all_nodes = [0] + Neighbours.copy()
    v = len(all_nodes)
    V = list(range(v))
    N = V.copy()
    N.remove(0)
    
    def Del(i):
        F = V.copy()
        F.remove(i)
        return F
    
    m = gb.Model()
    x = m.addVars(v,v, vtype=GRB.BINARY, name='x')
    m.setObjective(sum([cost(all_nodes[i], all_nodes[j]) * x[i,j] for i,j in product(V,V)]))
    for i in N:
        m.addConstr(sum([x[i,j] for j in Del(i)]) == 1)
    for j in N:
        m.addConstr(sum([x[i,j] for i in Del(j)]) == 1)
        
    l = m.addVar(lb=0.0, vtype=GRB.INTEGER, name='L')
    Ls.append(l)
    m.addConstr(sum([x[0,j] for j in Del(0)]) == l)
    
    u = m.addVars(V, vtype=GRB.CONTINUOUS, name='u')
    for i,j in filter(lambda tup: tup[0] != tup[1], product(N,N)):
        m.addConstr(u[i] - u[j] + Q*x[i,j] <= Q - q[j])
    for i in V:
        m.addConstr(u[i] >= q[i])
    
    primary_models.append(m)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-09-12

# %%
for model in tqdm(primary_models):
    model.optimize();
# Out:
#   0%|                                                    | 0/60 [00:00<?, ?it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x0f0c0895
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [3e+02, 3e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 156449.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 81504.000000
#
# Root relaxation: objective 4.697800e+04, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 46978.0000    0    3 81504.0000 46978.0000  42.4%     -    0s
# H    0     0                    81235.000000 46978.0000  42.2%     -    0s
#      0     0 infeasible    0      81235.0000 81235.0000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 3
#
# Explored 1 nodes (10 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 81235 81504 156449
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.123500000000e+04, best bound 8.123500000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x2daa063f
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [3e+02, 6e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 366646.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 133041.00000
#
# Root relaxation: objective 2.237474e+04, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 22374.7407    0    6 133041.000 22374.7407  83.2%     -    0s
# H    0     0                    129103.00000 22374.7407  82.7%     -    0s
#      0     0 129103.000    0    6 129103.000 129103.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 4
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 129103 133041 366646
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.291030000000e+05, best bound 1.291030000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x28dd9e5a
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [7e+01, 7e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 291205.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 172150.00000
#
# Root relaxation: objective 1.128257e+05, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 112825.667    0    3 172150.000 112825.667  34.5%     -    0s
# H    0     0                    160396.00000 112825.667  29.7%     -    0s
#      0     0 infeasible    0      160396.000 160396.000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 3
#
# Explored 1 nodes (10 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 160396 172150 291205
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.603960000000e+05, best bound 1.603960000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x541c2e31
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [3e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 264386.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 88508.000000
#
# Root relaxation: objective 6.220000e+02, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  622.00000    0    6 88508.0000  622.00000  99.3%     -    0s
#      0     0 infeasible    0      88508.0000 88508.0000  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 88508 264386
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.850800000000e+04, best bound 8.850800000000e+04, gap 0.0000%
#   7%|██▉                                         | 4/60 [00:00<00:01, 36.13it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x4490a5b1
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 242578.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 160490.00000
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 160490 242578
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.604900000000e+05, best bound 1.604900000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x6e100e60
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+04, 5e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 270183.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 90061.000000
#
# Root relaxation: objective 0.000000e+00, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    6 90061.0000    0.00000   100%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 90061 270183
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.006100000000e+04, best bound 9.006100000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xb086cc00
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+02, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 142014.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 50350.000000
#
# Root relaxation: objective 4.276519e+03, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4276.51852    0    6 50350.0000 4276.51852  91.5%     -    0s
# H    0     0                    50250.000000 4276.51852  91.5%     -    0s
# H    0     0                    49886.000000 4276.51852  91.4%     -    0s
#      0     0 49504.2222    0    5 49886.0000 49504.2222  0.77%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 2
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 49886 50250 50350 142014
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.988600000000e+04, best bound 4.988600000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xb8703113
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+04, 9e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 384699.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 204332.00000
#
# Root relaxation: objective 1.041557e+05, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 104155.667    0    3 204332.000 104155.667  49.0%     -    0s
# H    0     0                    203286.00000 104155.667  48.8%     -    0s
#      0     0 194720.444    0    5 203286.000 194720.444  4.21%     -    0s
#      0     0 194720.444    0    5 203286.000 194720.444  4.21%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 1
#
# Explored 1 nodes (11 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 203286 204332 384699
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.032860000000e+05, best bound 2.032860000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x731a53ec
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 241708.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 123161.00000
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 123161 241708
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.231610000000e+05, best bound 1.231610000000e+05, gap 0.0000%
#  15%|██████▌                                     | 9/60 [00:00<00:01, 39.03it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x0d34065e
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [3e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 174796.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 166408.00000
#
# Root relaxation: objective 1.577590e+05, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 157759.000    0    2 166408.000 157759.000  5.20%     -    0s
# H    0     0                    157759.00000 157759.000  0.00%     -    0s
#      0     0 157759.000    0    2 157759.000 157759.000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 157759 166408 174796
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.577590000000e+05, best bound 1.577590000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x7b73d713
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [5e+02, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 291918.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 195172.00000
#
# Root relaxation: objective 9.842600e+04, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 98426.0000    0    2 195172.000 98426.0000  49.6%     -    0s
# H    0     0                    98426.000000 98426.0000  0.00%     -    0s
#      0     0 98426.0000    0    2 98426.0000 98426.0000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 98426 195172 291918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.842600000000e+04, best bound 9.842600000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x6a8f4388
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+03, 7e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 324121.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 131094.00000
#
# Root relaxation: objective 6.007900e+04, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 60079.0000    0    6 131094.000 60079.0000  54.2%     -    0s
# H    0     0                    129870.00000 60079.0000  53.7%     -    0s
#      0     0 113475.111    0    6 129870.000 113475.111  12.6%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 6
#   RLT: 3
#
# Explored 1 nodes (12 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 129870 131094 324121
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.298700000000e+05, best bound 1.298700000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x6ca821d9
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [6e+02, 9e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 309868.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 204164.00000
#
# Root relaxation: objective 1.603110e+05, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 160311.000    0    3 204164.000 160311.000  21.5%     -    0s
# H    0     0                    203506.00000 160311.000  21.2%     -    0s
#      0     0 193424.444    0    1 203506.000 193424.444  4.95%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 3
#
# Explored 1 nodes (11 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 203506 204164 309868
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.035060000000e+05, best bound 2.035060000000e+05, gap 0.0000%
#  22%|█████████▎                                 | 13/60 [00:00<00:01, 36.02it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xcf3dd4e3
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [7e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 255540.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 86039.000000
#
# Root relaxation: objective 1.332000e+03, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1332.00000    0    6 86039.0000 1332.00000  98.5%     -    0s
# H    0     0                    85451.000000 1332.00000  98.4%     -    0s
#      0     0 48391.4444    0    6 85451.0000 48391.4444  43.4%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 10
#   RLT: 3
#
# Explored 1 nodes (12 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 85451 86039 255540
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.545100000000e+04, best bound 8.545100000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x9335fb75
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [5e+02, 3e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 162025.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 59952.000000
#
# Root relaxation: objective 1.839500e+04, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 42473.4444    0    1 59952.0000 42473.4444  29.2%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 59952 162025
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.995200000000e+04, best bound 5.995200000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x20561c29
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [8e+02, 6e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 204234.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 130855.00000
#
# Root relaxation: objective 9.098400e+04, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 90984.0000    0    3 130855.000 90984.0000  30.5%     -    0s
# H    0     0                    130076.00000 90984.0000  30.1%     -    0s
#      0     0 128845.111    0    3 130076.000 128845.111  0.95%     -    0s
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 130076 130855 204234
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300760000000e+05, best bound 1.300760000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x3c3c33d0
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+02, 7e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 186759.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 122914.00000
#
# Root relaxation: objective 8.446967e+04, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 84469.6667    0    3 122914.000 84469.6667  31.3%     -    0s
#      0     0 121683.111    0    3 122914.000 121683.111  1.00%     -    0s
#
# Cutting planes:
#   MIR: 5
#
# Explored 1 nodes (6 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 122914 186759
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.229140000000e+05, best bound 1.229140000000e+05, gap 0.0000%
#  28%|████████████▏                              | 17/60 [00:00<00:01, 36.38it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x10c94e88
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+03, 6e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 315992.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 116086.00000
#
# Root relaxation: objective 1.931800e+04, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 19318.0000    0    6 116086.000 19318.0000  83.4%     -    0s
# H    0     0                    116075.00000 19318.0000  83.4%     -    0s
#      0     0 76010.7778    0    6 116075.000 76010.7778  34.5%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 10
#   RLT: 3
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 116075 116086 315992
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.160750000000e+05, best bound 1.160750000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xd597f4ef
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [7e+02, 9e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 382435.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 201638.00000
#
# Root relaxation: objective 1.113667e+05, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 111366.667    0    3 201638.000 111366.667  44.8%     -    0s
# H    0     0                    200824.00000 111366.667  44.5%     -    0s
#      0     0 infeasible    0      200824.000 200824.000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 3
#
# Explored 1 nodes (8 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 200824 201638 382435
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.008240000000e+05, best bound 2.008240000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x350e891e
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 272022.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 183445.00000
#
# Root relaxation: objective 9.608100e+04, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 96081.0000    0    2 183445.000 96081.0000  47.6%     -    0s
# H    0     0                    96081.000000 96081.0000  0.00%     -    0s
#      0     0 96081.0000    0    2 96081.0000 96081.0000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96081 183445 272022
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.608100000000e+04, best bound 9.608100000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xc812a9da
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 560024.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 249879.00000
#
# Root relaxation: objective 1.347787e+05, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 134778.667    0    3 249879.000 134778.667  46.1%     -    0s
#      0     0 166094.630    0    6 249879.000 166094.630  33.5%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 4
#
# Explored 1 nodes (8 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 249879 560024
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.498790000000e+05, best bound 2.498790000000e+05, gap 0.0000%
#  35%|███████████████                            | 21/60 [00:00<00:01, 34.55it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xad0cec4c
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 195995.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 140293.00000
#
# Root relaxation: objective 8.475500e+04, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 84755.0000    0    2 140293.000 84755.0000  39.6%     -    0s
# H    0     0                    84755.000000 84755.0000  0.00%     -    0s
#      0     0 84755.0000    0    2 84755.0000 84755.0000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 84755 140293 195995
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.475500000000e+04, best bound 8.475500000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xf597daf1
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 305452.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 269378.00000
#
# Root relaxation: objective 2.283150e+05, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 228315.000    0    2 269378.000 228315.000  15.2%     -    0s
# H    0     0                    228315.00000 228315.000  0.00%     -    0s
#      0     0 228315.000    0    2 228315.000 228315.000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 228315 269378 305452
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.283150000000e+05, best bound 2.283150000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xa00b792c
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+01, 5e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 274006.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 96785.000000
#
# Root relaxation: objective 6.408333e+03, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6408.33333    0    6 96785.0000 6408.33333  93.4%     -    0s
# H    0     0                    93687.000000 6408.33333  93.2%     -    0s
#      0     0 56545.0000    0    5 93687.0000 56545.0000  39.6%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 2
#   RLT: 2
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 93687 96785 274006
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.368700000000e+04, best bound 9.368700000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x89e36cdb
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [9e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 296677.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 202391.00000
#
# Root relaxation: objective 1.148970e+05, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 114897.000    0    2 202391.000 114897.000  43.2%     -    0s
# H    0     0                    114897.00000 114897.000  0.00%     -    0s
#      0     0 114897.000    0    2 114897.000 114897.000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 114897 202391 296677
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.148970000000e+05, best bound 1.148970000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x020395df
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [5e+02, 9e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 366220.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 191156.00000
#
# Root relaxation: objective 1.069867e+05, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 122640.185    0    5 191156.000 122640.185  35.8%     -    0s
# H    0     0                    191017.00000 122640.185  35.8%     -    0s
#
# Cutting planes:
#   MIR: 2
#   RLT: 1
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 191017 191156 366220
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.910170000000e+05, best bound 1.910170000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x721e3517
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+03, 5e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 290155.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 98820.000000
#
# Root relaxation: objective 7.404000e+03, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7404.00000    0    6 98820.0000 7404.00000  92.5%     -    0s
#      0     0 infeasible    0      98820.0000 98820.0000  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 98820 290155
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.882000000000e+04, best bound 9.882000000000e+04, gap 0.0000%
#  45%|███████████████████▎                       | 27/60 [00:00<00:00, 40.80it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x07016aff
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 256548.00000
# Presolve removed 11 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 5 columns, 14 nonzeros
# Variable types: 3 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 171032.00000
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 171032 256548
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.710320000000e+05, best bound 1.710320000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xb5bd46c3
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 153171.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 108772.00000
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 108772 153171
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.087720000000e+05, best bound 1.087720000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x2982bd3a
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 132734.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 119682.00000
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 119682 132734
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.196820000000e+05, best bound 1.196820000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xb45ba010
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+04, 3e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 150882.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 61386.000000
#
# Root relaxation: objective 3.182100e+04, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 31821.0000    0    3 61386.0000 31821.0000  48.2%     -    0s
#      0     0 48652.2222    0    1 61386.0000 48652.2222  20.7%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Clique: 1
#   MIR: 3
#   RLT: 1
#
# Explored 1 nodes (9 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 61386 150882
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.138600000000e+04, best bound 6.138600000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xe2623b1a
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 276405.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 94089.000000
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 94089 276405
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.408900000000e+04, best bound 9.408900000000e+04, gap 0.0000%
#  53%|██████████████████████▉                    | 32/60 [00:00<00:00, 38.69it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x9cb4084e
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+04, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 189685.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 101486.00000
#
# Root relaxation: objective 6.960900e+04, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 69609.0000    0    3 101486.000 69609.0000  31.4%     -    0s
# H    0     0                    97285.000000 69609.0000  28.4%     -    0s
#      0     0 infeasible    0      97285.0000 97285.0000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 3
#   RLT: 1
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 97285 101486 189685
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.728500000000e+04, best bound 9.728500000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x76260825
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [3e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 181455.00000
# Presolve removed 11 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 5 columns, 14 nonzeros
# Variable types: 3 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 120970.00000
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 120970 181455
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.209700000000e+05, best bound 1.209700000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x8d845ee2
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [9e+02, 5e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 301682.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 112910.00000
#
# Root relaxation: objective 3.394000e+04, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 33940.0000    0    6 112910.000 33940.0000  69.9%     -    0s
#      0     0 93505.5556    0    6 112910.000 93505.5556  17.2%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 7
#   RLT: 3
#
# ...
# Best objective 1.510210000000e+05, best bound 1.510210000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x79b81c4e
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+02, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 477477.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 318542.00000
#
# Root relaxation: objective 1.596070e+05, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 159607.000    0    2 318542.000 159607.000  49.9%     -    0s
# H    0     0                    159607.00000 159607.000  0.00%     -    0s
#      0     0 159607.000    0    2 159607.000 159607.000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 159607 318542 477477
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.596070000000e+05, best bound 1.596070000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x1ee81fe4
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [2e+03, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 249983.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 86736.000000
#
# Root relaxation: objective 7.043519e+03, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7043.51852    0    6 86736.0000 7043.51852  91.9%     -    0s
#      0     0 86736.0000    0    6 86736.0000 86736.0000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 4
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 86736 249983
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.673600000000e+04, best bound 8.673600000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x4c5702c6
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 363607.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 217240.00000
#
# Root relaxation: objective 1.467823e+05, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 146782.296    0    6 217240.000 146782.296  32.4%     -    0s
# H    0     0                    213333.00000 146782.296  31.2%     -    0s
#      0     0 213333.000    0    5 213333.000 213333.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 4
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 213333 217240 363607
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.133330000000e+05, best bound 2.133330000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x0e575130
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [3e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 250810.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 171955.00000
#
# Root relaxation: objective 9.280700e+04, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 92807.0000    0    2 171955.000 92807.0000  46.0%     -    0s
# H    0     0                    92807.000000 92807.0000  0.00%     -    0s
#      0     0 92807.0000    0    2 92807.0000 92807.0000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 92807 171955 250810
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.280700000000e+04, best bound 9.280700000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xefcbe86d
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+03, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 379820.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 205635.00000
#
# Root relaxation: objective 1.206061e+05, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 120606.074    0    6 205635.000 120606.074  41.3%     -    0s
# H    0     0                    205451.00000 120606.074  41.3%     -    0s
# H    0     0                    204628.00000 120606.074  41.1%     -    0s
#      0     0 204628.000    0    5 204628.000 204628.000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 4
#   RLT: 2
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 204628 205451 205635 379820
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.046280000000e+05, best bound 2.046280000000e+05, gap 0.0000%
#  90%|██████████████████████████████████████▋    | 54/60 [00:01<00:00, 38.27it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xaab03ff5
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [3e+03, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 226367.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 84703.000000
#
# Root relaxation: objective 1.681519e+04, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 16815.1852    0    6 84703.0000 16815.1852  80.1%     -    0s
# H    0     0                    83152.000000 16815.1852  79.8%     -    0s
#      0     0 83152.0000    0    6 83152.0000 83152.0000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 4
#
# Explored 1 nodes (12 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 83152 84703 226367
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.315200000000e+04, best bound 8.315200000000e+04, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x355c4667
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [4e+04, 8e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 331631.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 161830.00000
#
# Root relaxation: objective 8.190000e+04, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 81900.0000    0    6 161830.000 81900.0000  49.4%     -    0s
# H    0     0                    161640.00000 81900.0000  49.3%     -    0s
#      0     0 126305.556    0    6 161640.000 126305.556  21.9%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 10
#   RLT: 3
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 161640 161830 331631
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.616400000000e+05, best bound 1.616400000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xaa42cac1
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [7e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 270323.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 185589.00000
#
# Root relaxation: objective 1.005750e+05, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 100575.000    0    2 185589.000 100575.000  45.8%     -    0s
# H    0     0                    100575.00000 100575.000  0.00%     -    0s
#      0     0 100575.000    0    2 100575.000 100575.000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 100575 185589 270323
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.005750000000e+05, best bound 1.005750000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0x176131fc
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [8e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 296463.00000
# Presolve removed 5 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 9 columns, 30 nonzeros
# Variable types: 3 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 202106.00000
#
# Root relaxation: objective 1.545713e+05, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 154571.333    0    3 202106.000 154571.333  23.5%     -    0s
#      0     0 196671.111    0    1 202106.000 196671.111  2.69%     -    0s
#
# Cutting planes:
#   Learned: 1
#   MIR: 3
#
# Explored 1 nodes (10 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 202106 296463
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.021060000000e+05, best bound 2.021060000000e+05, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xda85af50
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [5e+04, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 396360.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 312304.00000
#
# Root relaxation: objective 2.274250e+05, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 227425.000    0    2 312304.000 227425.000  27.2%     -    0s
# H    0     0                    227425.00000 227425.000  0.00%     -    0s
#      0     0 227425.000    0    2 227425.000 227425.000  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 227425 312304 396360
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.274250000000e+05, best bound 2.274250000000e+05, gap 0.0000%
#  98%|██████████████████████████████████████████▎| 59/60 [00:01<00:00, 38.60it/s]
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 21 columns and 44 nonzeros
# Model fingerprint: 0xb1139d86
# Variable types: 4 continuous, 17 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [6e+03, 1e+08]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+00]
# Found heuristic solution: objective 252882.00000
# Presolve removed 9 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 7 columns, 20 nonzeros
# Variable types: 3 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 95183.000000
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 95183 252882
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.518300000000e+04, best bound 9.518300000000e+04, gap 0.0000%
# 100%|███████████████████████████████████████████| 60/60 [00:01<00:00, 37.36it/s]

# %%
model_solutions = {}
for i,model in enumerate(primary_models):
    soln = json.loads(model.getJSONSolution())
    model_solutions[i] = soln
json.dump(model_solutions, open('./primary_model_solutions.json', 'w'), indent=4)

# %%
s = 0
for model in primary_models:
    s += model.ObjVal
s
# Out:
# 7756315.0
