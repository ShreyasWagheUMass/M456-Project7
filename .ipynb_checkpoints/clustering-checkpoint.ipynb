# %%
import scipy as sp
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
locs = pd.read_json('./cleandata/locations.json')

# %%
locs
# Out:
#      loc_id                                    title       type  \
# 0         0                         FBWM - Warehouse  Warehouse
# 1         1                  Amherst Survival Center     Agency
# 2         2                  Palmer Food Share, Inc.     Agency
# 3         3  Franklin County Community Meals Program     Agency
# 4         4                     Freedom House of God     Agency
# ..      ...                                      ...        ...
# 132     132                           Riverland Farm    Pick-up
# 133     133                           Next Barn Over    Pick-up
# 134     134                              Warner Farm    Pick-up
# 135     135                           Kitchen Garden    Pick-up
# 136     136                            Red Fire Farm    Pick-up
#
#                    street1         city         zip state       long  \
# 0     97 North Hatfield Rd     Hatfield       01038    MA -72.614765
# 1      138 Sunderland Road      Amherst       01002    MA -72.532890
# 2         39 Walnut Street       Palmer  01069-1731    MA -72.325910
# 3     118 East Main Street       Orange       01364    MA -72.304770
# 4         563 Union Street  Springfield  01139-0187    MA -72.571030
# ..                     ...          ...         ...   ...        ...
# 132          206 River Rd.   Sunderland       01375    MA -72.584480
# 133  15 Lawrence Plain Rd.       Hadley       01035    MA -72.577480
# 134      23 South Main St.   Sunderland       01375    MA -72.582070
# 135   131 South Silver Ln.   Sunderland       01375    MA -72.564480
# 136         184 Meadow Rd.     Montague       01351    MA -72.559460
#
#            lat
# 0    42.398013
# 1    42.414720
# 2    42.158240
# 3    42.590400
# 4    42.107610
# ..         ...
# 132  42.446040
# 133  42.329050
# 134  42.461950
# 135  42.446000
# 136  42.528910
#
# [137 rows x 9 columns]

# %%
locs = locs.loc[:124] # Get rid of pickup locations
locs
# Out:
#      loc_id                                    title              type  \
# 0         0                         FBWM - Warehouse         Warehouse
# 1         1                  Amherst Survival Center            Agency
# 2         2                  Palmer Food Share, Inc.            Agency
# 3         3  Franklin County Community Meals Program            Agency
# 4         4                     Freedom House of God            Agency
# ..      ...                                      ...               ...
# 120     120                             Urban League  Mobile Food Bank
# 121     121               Westfield Mobile Food Bank  Mobile Food Bank
# 122     122                   Our Lady of the Valley  Mobile Food Bank
# 123     123                           Grenville Park  Mobile Food Bank
# 124     124                             The Boulders  Mobile Food Bank
#
#                     street1         city         zip state       long  \
# 0      97 North Hatfield Rd     Hatfield       01038    MA -72.614765
# 1       138 Sunderland Road      Amherst       01002    MA -72.532890
# 2          39 Walnut Street       Palmer  01069-1731    MA -72.325910
# 3      118 East Main Street       Orange       01364    MA -72.304770
# 4          563 Union Street  Springfield  01139-0187    MA -72.571030
# ..                      ...          ...         ...   ...        ...
# 120              33 Oak St.  Springfield       01109    MA -72.573440
# 121            60 Broad St.    Westfield       01085    MA -72.748010
# 122            33 Adams St.  Easthampton       01027    MA -72.664750
# 123           73 Church St.         Ware       01082    MA -72.235330
# 124  156 Brittany Manor Dr.      Amherst       01002    MA -72.528840
#
#            lat
# 0    42.398013
# 1    42.414720
# 2    42.158240
# 3    42.590400
# 4    42.107610
# ..         ...
# 120  42.108240
# 121  42.117380
# 122  42.267910
# 123  42.264920
# 124  42.348770
#
# [125 rows x 9 columns]

# %%
longs = locs['long'].to_numpy()
lats = locs['lat'].to_numpy()

# %%
#Naive scatter plot of our delivery locations
plt.grid()
plt.scatter(longs, lats, alpha=0.5)
plt.scatter(longs[0], lats[0], color='red', label='FBWM Warehouse')
plt.ylabel('latitude')
plt.xlabel('longitude')
plt.title('FBWM Delivery Locations')
plt.legend()

# %%
long_lat_in_one = np.array([*zip(longs[1:],lats[1:])]) #Compress into one array for clustering, except the warehouse
long_lat_in_one = sp.cluster.vq.whiten(long_lat_in_one) # Remove noise from the data

# %%
from collections import defaultdict
def dict_with_list():
    return defaultdict(list)
k_to_dict_of_lists = defaultdict(dict_with_list)

for k in range(3,10,2):
    centroids, labels = sp.cluster.vq.kmeans2(long_lat_in_one, k = k)
    current_dict = k_to_dict_of_lists[k]
    for i,v in enumerate(labels):
        current_dict[v].append(i)
# Out:
# /Users/shreyasw/456/venv/lib/python3.10/site-packages/scipy/cluster/vq.py:603: UserWarning: One of the clusters is empty. Re-run kmeans with a different initialization.
#   warnings.warn("One of the clusters is empty. "

# %%
for Dict in k_to_dict_of_lists.values():
    new_one = defaultdict(list)
    for k,v in Dict.items():
