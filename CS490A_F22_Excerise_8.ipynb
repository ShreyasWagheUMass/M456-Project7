# %% [markdown]
# ## This Notebook contains code that you will use to answer the questions for Excercise 8

# %% [markdown]
# The first two code cells install and load the 🤗 transformers library

# %%
# Install 🤗 transformers library
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 182 kB 52.5 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 42.1 MB/s
# ...

# %%
from transformers import AutoTokenizer

# %% [markdown]
# The next code defines a function `get_tokenizer` which takes a model name ("bert", "roberta", or "gpt2") as input and returns a pretrained tokenizer for that model.

# %%
def get_tokenizer(model_name):
  if model_name == "bert":
    return AutoTokenizer.from_pretrained('bert-base-cased')
  elif model_name == "roberta":
    return AutoTokenizer.from_pretrained('roberta-base')
  elif model_name == 'gpt2':
    return AutoTokenizer.from_pretrained('gpt2')
  else:
    print("ERROR: Unexpected model name '{}'".format(model_name))

# %% [markdown]
# So, `tokenizer` is a pretrained tokenizer for BERT.

# %%
tokenizer = get_tokenizer('bert')
tokenizer2 = get_tokenizer('roberta')
tokenizer3 = get_tokenizer('gpt2')
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# The tokenizer's function `tokenize`, will return the tokenization of the input string.

# %%
tokenizer.tokenize(" The dog fetched the stick.")
# Out:
# ['The', 'dog', 'fetch', '##ed', 'the', 'stick', '.']

# %% [markdown]
# Notes for Problem I:
# - For consistency of comparison of tokenizers, be sure to **include a space before each word you want to tokenize**.
# - The leading symbol `Ġ` indicates the start of a new word token for some tokenizers
# - The leading sequence `##` indicates the continuation of a word token for some tokenizers

# %%
def token(x):
  print('bert: {}'.format(tokenizer.tokenize(x)))
  print('roberta: {}'.format(tokenizer2.tokenize(x)))
  print('gpt2: {}'.format(tokenizer3.tokenize(x)))

# %%
token(" disobedient")
# Out:
# bert: ['di', '##so', '##bed', '##ient']
# roberta: ['Ġdisob', 'edient']
# gpt2: ['Ġdisob', 'edient']

# %%
token(' misaligned')
# Out:
# bert: ['mi', '##sal', '##ign', '##ed']
# roberta: ['Ġmis', 'aligned']
# gpt2: ['Ġmis', 'aligned']

# %%
token(' trustworthy')
# Out:
# bert: ['trust', '##worthy']
# roberta: ['Ġtrustworthy']
# gpt2: ['Ġtrustworthy']

# %%
token(' happiness')
# Out:
# bert: ['happiness']
# roberta: ['Ġhappiness']
# gpt2: ['Ġhappiness']

# %%
token(' loveless')
# Out:
# bert: ['love', '##less']
# roberta: ['Ġlo', 'vel', 'ess']
# gpt2: ['Ġlo', 'vel', 'ess']

# %%
token(' papery')
# Out:
# bert: ['paper', '##y']
# roberta: ['Ġpap', 'ery']
# gpt2: ['Ġpap', 'ery']

# %%
token(' believers')
# Out:
# bert: ['believers']
# roberta: ['Ġbelievers']
# gpt2: ['Ġbelievers']

# %%
token(' mindful')
# Out:
# bert: ['mind', '##ful']
# roberta: ['Ġmindful']
# gpt2: ['Ġmindful']

# %%
token(' not')
# Out:
# bert: ['not']
# roberta: ['Ġnot']
# gpt2: ['Ġnot']

# %%
token(' scarred')
# Out:
# bert: ['scarred']
# roberta: ['Ġscar', 'red']
# gpt2: ['Ġscar', 'red']

# %%
token(' donkey')
# Out:
# bert: ['don', '##key']
# roberta: ['Ġdonkey']
# gpt2: ['Ġdonkey']
